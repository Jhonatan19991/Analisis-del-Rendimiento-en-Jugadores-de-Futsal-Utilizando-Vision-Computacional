# %% [markdown]
# ### 🧹 Limpieza de etiquetas YOLO
#
# Este script recorre las carpetas `train`, `valid` y `test` de un dataset con estructura YOLO. Para cada imagen:
#
# - Verifica si existe su archivo de etiquetas.
# - Elimina las clases 0 y 2.
# - Reasigna la clase 1 a 0 y la clase 3 a 1.
# - Si una imagen no tiene etiquetas válidas después del filtro, elimina tanto la imagen como su archivo de etiquetas.
#
# Con esto se reorganizan las clases y se limpia el dataset automáticamente.

# %%
import os
import shutil

def process_labels(images_dir, labels_dir):
    # Listar todas las imágenes
    for img_file in os.listdir(images_dir):
        if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
            base_name = os.path.splitext(img_file)[0]
            txt_file = os.path.join(labels_dir, base_name + '.txt')
            
            # Si no existe el archivo de etiquetas, saltar
            if not os.path.exists(txt_file):
                continue
            
            # Leer y procesar etiquetas
            new_lines = []
            with open(txt_file, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    
                    if len(parts) != 5:
                        continue
                    
                    class_id = int(parts[0])
                    
                    # Eliminar clases 0 y 2
                    if class_id in {0, 2}:
                        continue
                    
                    # Cambiar clase 3 a 2
                    if class_id == 1:
                        parts[0] = '0'
                    if class_id == 3:
                        parts[0] = '1'
                    
                    new_lines.append(' '.join(parts))
            
            # Si no quedan etiquetas, eliminar archivos
            if not new_lines:
                os.remove(txt_file)
                img_path = os.path.join(images_dir, img_file)
                os.remove(img_path)
                print(f"Eliminados: {img_file} y su etiqueta")
            else:
                # Escribir nuevas etiquetas
                with open(txt_file, 'w') as f:
                    f.write('\n'.join(new_lines))

# Directorios base (cambiar según tu estructura)
data_dir = 'E:/Futsal/dataset'
splits = ['train', 'valid', 'test']

for split in splits:
    print(f"\nProcesando: {split}")
    images_dir = os.path.join(data_dir, split, 'images')
    labels_dir = os.path.join(data_dir, split, 'labels')
    
    if not os.path.exists(images_dir) or not os.path.exists(labels_dir):
        print(f"Error: Directorios no encontrados para {split}")
        continue
    
    process_labels(images_dir, labels_dir)

print("\n¡Proceso completado!")
# Out:
# Procesando: train
# Eliminados: 0008_57468_jpg.rf.733786c1a0b0deccc477e86da5cc3ab1.jpg y su etiqueta
# Eliminados: 0008_57468_jpg.rf.988b5e047aed5a90574581125966d85f.jpg y su etiqueta
# Eliminados: 0008_57468_jpg.rf.9ee000a190defa67f3570c3228b6dd5a.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.6911fa6e1dec6fee8a44d2ed5d954f59.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.6914edb62874d6ab16b7613f0642a518.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.74001565d8a055345cd60265677ed846.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.8131a22c260f32b675e38a466984aa77.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.913a9908459feb5800a4e38483fa4212.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.bc4d2ba2e5de123b324114b9163f0f81.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.cb14bee16d3cfd67fc0075a6d8d06d6a.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.e2e40af12893a9139e45b9fb36888f3b.jpg y su etiqueta
# Eliminados: 0008_57469_jpg.rf.f3309deab43780bae601cb491d0d36e6.jpg y su etiqueta
# Eliminados: 0008_57470_jpg.rf.278132c3d7baef7fda541185144ae44c.jpg y su etiqueta
# Eliminados: 0008_57470_jpg.rf.861fed0efa51184e4c9849b3d532160d.jpg y su etiqueta
# Eliminados: 0008_57470_jpg.rf.8dd7dab79e8e5add5f3d748842017ada.jpg y su etiqueta
# Eliminados: 0008_57470_jpg.rf.b93df4390752c3bda4bea618edfbb29d.jpg y su etiqueta
# Eliminados: 0008_57470_jpg.rf.d58a826d8a88d23b20698a08b9ade92f.jpg y su etiqueta
# Eliminados: 0008_57470_jpg.rf.da39e2bfe38ef9f43277b724e04fff54.jpg y su etiqueta
# Eliminados: 0008_57471_jpg.rf
# Eliminados: youtube-44_jpg.rf.8d9b685a01621ca6c66b1f6a5c113f97.jpg y su etiqueta
# Eliminados: youtube-44_jpg.rf.a6f1b15a57fa5654c62d902aac23a691.jpg y su etiqueta
# Eliminados: youtube-45_jpg.rf.32bed38e6db2e95290602e86dbbecdef.jpg y su etiqueta
# Eliminados: youtube-48_jpg.rf.216657add8951fd96d056f71b9d116f5.jpg y su etiqueta
# Eliminados: youtube-48_jpg.rf.4df5cdc42689cae89e75022e88c32c74.jpg y su etiqueta
# Eliminados: youtube-49_jpg.rf.6eacb9bcb2737ca74e38f70501968cc2.jpg y su etiqueta
# Eliminados: youtube-49_jpg.rf.ca01632eaea880daa5c7ccd5f6aa37aa.jpg y su etiqueta
# Eliminados: youtube-4_jpg.rf.40ce40b242ed1ff02dc9ae0562164b64.jpg y su etiqueta
# Eliminados: youtube-50_jpg.rf.3d98dabf0909e03fe72acd55f6fdb7c4.jpg y su etiqueta
# Eliminados: youtube-50_jpg.rf.b23792c70cdbf41edce1332a7e919cbb.jpg y su etiqueta
# Eliminados: youtube-52_jpg.rf.9ce4b0866fab54b722ef80db4d122ff7.jpg y su etiqueta
# Eliminados: youtube-53_jpg.rf.258d471eb5af6819829671e96446b479.jpg y su etiqueta
# Eliminados: youtube-54_jpg.rf.52cc846411643645284b42848764a9a9.jpg y su etiqueta
# Eliminados: youtube-56_jpg.rf.62732be8698b1a919f647d2d9a53890e.jpg y su etiqueta
# Eliminados: youtube-57_jpg.rf.9694c3aba2a36f143b57a1c9cc78814a.jpg y su etiqueta
# Eliminados: youtube-59_jpg.rf.dcca4b2b25ff737aac1f7a410a2b7851.jpg y su etiqueta
# Eliminados: youtube-60_jpg.rf.973dab8088d875f29261b243e1287790.jpg y su etiqueta
# Eliminados: youtube-61_jpg.rf.3a92bf0dcaa92f39629ada1f6d01fe26.jpg y su etiqueta
# Eliminados: youtube-62_jpg.rf.03e802ba82afca54aa5499d8ca044998.jpg y su etiqueta
# Eliminados: youtube-64_jpg.rf.4a2b4ecfe1d3eb23ff5d7abedc343235.jpg y su etiqueta
# Eliminados: youtube-66_jpg.rf.99a9251455a82da4589673fce18047d9.jpg y su etiqueta
# Eliminados: youtube-68_jpg.rf.77bb764451fe67764bb4487801d633cf.jpg y su etiqueta
# Eliminados: youtube-70_jpg.rf.353c878a680ba48545e6b4b369527fdb.jpg y su etiqueta
# Eliminados: youtube-70_jpg.rf.67225064763a4ffe2cdbe75c923a85b9.jpg y su etiqueta
# Eliminados: youtube-72_jpg.rf.b7f319abac332044da133977add18ee1.jpg y su etiqueta
# Eliminados: youtube-73_jpg.rf.5bdd438b5dff0502820fe08d5416f1ec.jpg y su etiqueta
# Eliminados: youtube-74_jpg.rf.a5b0cd4826484a1f609abaaef0f8f5a9.jpg y su etiqueta
# Eliminados: youtube-76_jpg.rf.d3dc1dfaf8b0116958645bfecb634524.jpg y su etiqueta
# Eliminados: youtube-78_jpg.rf.cf1b7a64f68632bbf9904a1bc9c480d5.jpg y su etiqueta
# Eliminados: youtube-81_jpg.rf.d8f81365fa1d253ebcd76c0036bd089f.jpg y su etiqueta
# Eliminados: youtube-86_jpg.rf.367481c0f5c3e9d045842750d0888094.jpg y su etiqueta
# Eliminados: youtube-88_jpg.rf.49ed6d34509538cb93d74fc2ebd6afda.jpg y su etiqueta
# Eliminados: youtube-88_jpg.rf.954e841cb068791da0f518f4ca520392.jpg y su etiqueta
# Eliminados: youtube-89_jpg.rf.ecc6db3a5fd279fe752c8f770c703b26.jpg y su etiqueta
# Eliminados: youtube-94_jpg.rf.bbec293299ca2eabe1bd9f2906dd8029.jpg y su etiqueta
# Eliminados: youtube-95_jpg.rf.e643d13c49ed89c4095479320f7d1015.jpg y su etiqueta
# Eliminados: youtube-97_jpg.rf.326b24784c29cd78d8ac20b1f08ee252.jpg y su etiqueta
# Eliminados: youtube-97_jpg.rf.359bc1efe569714a41c1236b4780998d.jpg y su etiqueta
# Eliminados: youtube-98_jpg.rf.2d6a39f49d43c5f4028bd09b20784055.jpg y su etiqueta
# Eliminados: youtube-99_jpg.rf.63455fc9bb57aebbe30590b3e1d640af.jpg y su etiqueta
# Eliminados: youtube-9_jpg.rf.14ad0ef9daabe6eccccdf235926c777b.jpg y su etiqueta
# Eliminados: youtube-9_jpg.rf.8fdc0c48c628cc09ce928bdc0043369a.jpg y su etiqueta
#
# Procesando: test
# Eliminados: 0008_57479_jpg.rf.b76a62df96e8f67d0ae3d2088618eb29.jpg y su etiqueta
# Eliminados: 0008_57480_jpg.rf.b79958ba67075d16e7ce1449da45827e.jpg y su etiqueta
# Eliminados: 0008_57483_jpg.rf.164661afe54a2910a85f96693f3d9333.jpg y su etiqueta
# Eliminados: 0008_57505_jpg.rf.388114a7a3b84d6fd0c571030c87eefd.jpg y su etiqueta
# Eliminados: 0008_57520_jpg.rf.4181dc270d79eabe86e72867c3961bcb.jpg y su etiqueta
# Eliminados: 0008_71566_jpg.rf.32b2ea3735dea549c5b549b4b28d993b.jpg y su etiqueta
# Eliminados: 0008_71570_jpg.rf.63514cae7f8dbb1c0c92bea3eee45f4c.jpg y su etiqueta
# Eliminados: 0008_71612_jpg.rf.0dd51684c4f13fc3fafe4d0ac733c065.jpg y su etiqueta
# Eliminados: 0008_71619_jpg.rf.01417aba412026c01cdd40087ec31b3a.jpg y su etiqueta
# Eliminados: 1267_5329_jpg.rf.865401f26c38aadd53967fdda8c93996.jpg y su etiqueta
# Eliminados: 1267_5341_jpg.rf.3c2c85a9807c75993f7dcf48514f5b13.jpg y su etiqueta
# Eliminados: 1267_5347_jpg.rf.a50a217fd9320aaa8e07da24a87ee5bd.jpg y su etiqueta
# Eliminados: 1267_5354_jpg.rf.57ee6dc6ad985e14ae2d8f4e144b6bae.jpg y su etiqueta
# Eliminados: 1267_5373_jpg.rf.dcfb2fd878f700232f1fdd12a2bcd675.jpg y su etiqueta
# Eliminados: 1267_5375_jpg.rf.a46ff2d878868742e0eb9070171268a4.jpg y su etiqueta
# Eliminados: 1267_5377_jpg.rf.9bd42741ece0b562b58dbfcbffbc0751.jpg y su etiqueta
# Eliminados: 1267_5391_jpg.rf.06d50001601aff5922637f394378e720.jpg y su etiqueta
# Eliminados: 1267_5396_jpg.rf.709f8cb7281def66eeaa3b03db9afd8b.jpg y su etiqueta
# Eliminados: 1267_555_jpg.rf.478e05d12c7dbba73a775a2b1b9063d1.jpg y su etiqueta
# Eliminados: 1267_555_jpg.rf.fc7cfa0fd74fa8c63968835afc00f692.jpg y su etiqueta
# Eliminados: 1267_567_jpg.rf.2c0a0911aacbe010f28470db5ef4175e.jpg y su etiqueta
# Eliminados: 1267_576_jpg.rf.687d4dd273a556758f34ecf349a527ff.jpg y su etiqueta
# Eliminados: 1267_580_jpg.rf.82abfd7d38d556f352e77cb524f172c3.jpg y su etiqueta
# Eliminados: 1267_581_jpg.rf.cee6020acf912ccef581b36635a67567.jpg y su etiqueta
# Eliminados: 1267_585_jpg.rf.6b2fb3b1d8f546ffb40c3caf0414fd76.jpg y su etiqueta
# Eliminados: 1267_587_jpg.rf.925cedd57fefbbbd9ad514e3fba1fcaf.jpg y su etiqueta
# Eliminados: 1267_587_jpg.rf.fdbb9c3b0beb060abf5ff68ec4164775.jpg y su etiqueta
# Eliminados: 1267_590_jpg.rf.de8f6f693cda4c2616cb47de83409f2a.jpg y su etiqueta
# Eliminados: 1267_592_jpg.rf.92fa83bd19df310c8a8dbcc6275acc31.jpg y su etiqueta
# Eliminados: 1267_60240_jpg.rf.f76a313f7b48765f8e488b78edd317d3.jpg y su etiqueta
# Eliminados: 1267_60241_jpg.rf.3fee62d6ee5abbc50007ac3a46471154.jpg y su etiqueta
# Eliminados: 1267_60242_jpg.rf.3c547334fc4afcfb61768847fa007c1e.jpg y su etiqueta
# Eliminados: 1267_60251_jpg.rf.cbe847335bf8c1563250bcde4a38c94e.jpg y su etiqueta
# Eliminados: 1267_60275_jpg.rf.494af08335db309aabf59e5c33ac7c0b.jpg y su etiqueta
# Eliminados: 1267_60285_jpg.rf.fe44707fbda1928b9ef9cfdd1653775b.jpg y su etiqueta
# Eliminados: 1267_60300_jpg.rf.569fda7215fc9211d6ff3e5d17ef5dd2.jpg y su etiqueta
# Eliminados: 1267_60310_jpg.rf.9ca524ce44754d7af34796e06ab59f96.jpg y su etiqueta
# Eliminados: 1267_60314_jpg.rf.6d62feb6341b10a08ca34d2892272d23.jpg y su etiqueta
# Eliminados: 1270_265_jpg.rf.c8fb6c85d5abc4dad61adacf321d0d80.jpg y su etiqueta
# Eliminados: 1270_271_jpg.rf.6cf9f27d0b303baed6c37e3b80995822.jpg y su etiqueta
# Eliminados: 1270_274_jpg.rf.ba689b4f9732d0e1b3c240319b28696f.jpg y su etiqueta
# Eliminados: 1270_278_jpg.rf.ad923e71fc78e9c9ae704c213d88198f.jpg y su etiqueta
# Eliminados: 1270_279_jpg.rf.edc52ca004f4722e803f28c7856efb23.jpg y su etiqueta
# Eliminados: 1270_299_jpg.rf.d29238486372d0bbeb919bb2fc2c1943.jpg y su etiqueta
# Eliminados: 1270_305_jpg.rf.6f9136251e1990b55814d7e748330e4d.jpg y su etiqueta
# Eliminados: 1270_305_jpg.rf.884d41341a89dfb1af2e8ca8ee8e9d15.jpg y su etiqueta
# Eliminados: 1270_349_jpg.rf.f7fe0ab84fe58d180424df1bc20af8e3.jpg y su etiqueta
# Eliminados: 1270_42108_jpg.rf.af3b01221a30d0adf892a21e8a0f12e5.jpg y su etiqueta
# Eliminados: 1270_42110_jpg.rf.e5194ff5504464a889f20a72f6442646.jpg y su etiqueta
# Eliminados: 1270_42122_jpg.rf.59b74498d093d5ac7676c82f4cf7faea.jpg y su etiqueta
# Eliminados: 1270_42134_jpg.rf.bf022d0643332f60c99a4e43c043cf72.jpg y su etiqueta
# Eliminados: 1270_42147_jpg.rf.7c549dd765de4d22de3bc6afde90328c.jpg y su etiqueta
# Eliminados: 1270_42152_jpg.rf.51c539f1ee90bd3f1a435728a1ba0962.jpg y su etiqueta
# Eliminados: 1270_42158_jpg.rf.375b08ce9961512d1d04ad766be4e860.jpg y su etiqueta
# Eliminados: 1270_42188_jpg.rf.637385076efdbee59e41e2a8da15e89e.jpg y su etiqueta
# Eliminados: 1270_42212_jpg.rf.d7ff1115f54b4cb662282f0ea59a8434.jpg y su etiqueta
# Eliminados: 1270_7865_jpg.rf.994522c14c5c78f5562cf81189e37934.jpg y su etiqueta
# Eliminados: 1270_7868_jpg.rf.54472e3cf3d1ad8a97d04f7d4a444624.jpg y su etiqueta
# Eliminados: 1270_7870_jpg.rf.ea300961a8cb3fb7640e5d4231e1f509.jpg y su etiqueta
# Eliminados: 1270_7883_jpg.rf.c76a72792512a886a3e5a2835df20abf.jpg y su etiqueta
# Eliminados: 1270_7884_jpg.rf.bf267c3099d8230086f9541dcf59ef19.jpg y su etiqueta
# Eliminados: 1270_7888_jpg.rf.faa5ebe34c4b61ef0a89a71b3f2cb8ff.jpg y su etiqueta
# Eliminados: 1270_7902_jpg.rf.6c3312874ce36261d91dcd3500a93646.jpg y su etiqueta
# Eliminados: 1270_7923_jpg.rf.8148cd5c06bb7e6e311c1ede8679876f.jpg y su etiqueta
# Eliminados: 1270_7961_jpg.rf.39c5a6ef10f95591ff044cb6ce0f8427.jpg y su etiqueta
# Eliminados: 1312_60874_jpg.rf.d96daf1069a5c050f31308dcc6fbc97c.jpg y su etiqueta
# Eliminados: 1312_60905_jpg.rf.5f78b2dc40ce651e0b34e8e3e63c2ca8.jpg y su etiqueta
# Eliminados: 1312_60907_jpg.rf.62370780dab258a6bc4ff976911c6c74.jpg y su etiqueta
# Eliminados: 1312_60912_jpg.rf.766a2651edfb6738389c35ca145b6684.jpg y su etiqueta
# Eliminados: 1312_60924_jpg.rf.e1172c5c48c166c89d1b787f6d5aa22e.jpg y su etiqueta
# Eliminados: 1312_60935_jpg.rf.c68fcf93da0350bf2b5bc8422df06298.jpg y su etiqueta
# Eliminados: 1312_60938_jpg.rf.28bff9d28a9e630d702afa46ab1be901.jpg y su etiqueta
# Eliminados: 1312_60956_jpg.rf.2781bf5ce3a7947c71e455f0c1a74bfb.jpg y su etiqueta
# Eliminados: 1312_60958_jpg.rf.62966c7b3046ba78700dbe02f25d7de8.jpg y su etiqueta
# Eliminados: 1312_75138_jpg.rf.11116a8ff89dd1fcf26a204b5c55e6e7.jpg y su etiqueta
# Eliminados: 1312_75141_jpg.rf.6cccc24dc978d69941bfff1985f4ab0e.jpg y su etiqueta
# Eliminados: 1312_75144_jpg.rf.82468db24c5a03f307a063a5371cd244.jpg y su etiqueta
# Eliminados: 1312_75149_jpg.rf.9e19961b9edd55841c271fbe14f53d10.jpg y su etiqueta
# Eliminados: 1312_75158_jpg.rf.357f9197f2fceed9eb8a09948bc8a009.jpg y su etiqueta
# Eliminados: 1312_75167_jpg.rf.4fe37fee092232169110cd075cd01c00.jpg y su etiqueta
# Eliminados: 1312_75183_jpg.rf.5e801075ee95d0a723f1e7932560aba4.jpg y su etiqueta
# Eliminados: 1312_75184_jpg.rf.7e961c99805e9cdcac5b0ccc329899b0.jpg y su etiqueta
# Eliminados: 1312_75188_jpg.rf.6e09568e861f9d72b4cc7cce0eb9a716.jpg y su etiqueta
# Eliminados: 1312_75193_jpg.rf.a43039ed232d506a1aa4dbca34075fc5.jpg y su etiqueta
# Eliminados: 1312_75197_jpg.rf.e2683afcefb9c61b99d5c0a994779724.jpg y su etiqueta
# Eliminados: 1312_75203_jpg.rf.2d0680613179a68a00106e821c6fb514.jpg y su etiqueta
# Eliminados: 1312_75229_jpg.rf.864a8a29961b72038afe3101b04b1215.jpg y su etiqueta
# Eliminados: 1312_75232_jpg.rf.d7d761ba7dba0edd59f58624e3d7fd4e.jpg y su etiqueta
# Eliminados: 1312_75235_jpg.rf.fefb7854a1b4380afc376b38d9e284ea.jpg y su etiqueta
# Eliminados: 1433_478_jpg.rf.1763d933908c10f8e74085d9c3e777aa.jpg y su etiqueta
# Eliminados: 1433_482_jpg.rf.f558565246ae6e68191f6c3eb50eda8a.jpg y su etiqueta
# Eliminados: 1433_490_jpg.rf.c6656db67f617ebb753c88695887157e.jpg y su etiqueta
# Eliminados: 1433_495_jpg.rf.f08fc91443e4ff43f859f4aaf75c1b58.jpg y su etiqueta
# Eliminados: 1433_502_jpg.rf.feb6c39f2c26c372a8fc52a05449c5f0.jpg y su etiqueta
# Eliminados: 1433_539_jpg.rf.a514f45030881bf6f071c86cdc95f41f.jpg y su etiqueta
# Eliminados: 1433_547_jpg.rf.e14d44b79c2020d07955134a5fde0551.jpg y su etiqueta
# Eliminados: 1433_550_jpg.rf.a8ae7f045a8a8f922a3894e40374eb68.jpg y su etiqueta
# Eliminados: 1433_58622_jpg.rf.6d5839e4d58f453411a19222e17ba2ca.jpg y su etiqueta
# Eliminados: 1433_58631_jpg.rf.df786d2d782a5fe7d423e41b048ad949.jpg y su etiqueta
# Eliminados: 1433_58642_jpg.rf.f25a5363fe3aba8d68519f06af24baa1.jpg y su etiqueta
# Eliminados: 1433_58656_jpg.rf.ccafaf95489917c1e8b53a97356a847c.jpg y su etiqueta
# Eliminados: 1433_58659_jpg.rf.8361cb03602bace9a3037fc63a316be6.jpg y su etiqueta
# Eliminados: 1433_58669_jpg.rf.6723fb87af2ccc5f226cb0b5e2e00537.jpg y su etiqueta
# Eliminados: 1433_58671_jpg.rf.2c1bfa6f3fc46a8331b95805636b0f9d.jpg y su etiqueta
# Eliminados: 1433_58673_jpg.rf.eb721e89d91e03ff69a50a933ce40850.jpg y su etiqueta
# Eliminados: 1433_58714_jpg.rf.d3a6947e95d2b0d57d5853c56cdd199b.jpg y su etiqueta
# Eliminados: 1433_58715_jpg.rf.ad71907a85ce1bda21a7af3f3573f2aa.jpg y su etiqueta
# Eliminados: 1433_58717_jpg.rf.b33ae1f674482ec0e74069edd8b7b297.jpg y su etiqueta
# Eliminados: 1433_58722_jpg.rf.8209c65bd886219e2ecff96759b85cc2.jpg y su etiqueta
# Eliminados: 1433_58724_jpg.rf.6f12195ec1c2f319add609e8119050a2.jpg y su etiqueta
# Eliminados: 1433_58732_jpg.rf.0265eefb7bb0bacdaea0786f40f18ecb.jpg y su etiqueta
# Eliminados: 1433_58744_jpg.rf.91cd5cfe1eb0685b745e02addc20bda6.jpg y su etiqueta
# Eliminados: 1433_58747_jpg.rf.ea1300dedce0ebcf15ccde2f016dee2d.jpg y su etiqueta
# Eliminados: 2001_129150_jpg.rf.6dbaab210ab9a15b3add854bdde15c65.jpg y su etiqueta
# Eliminados: 2001_129151_jpg.rf.e5a45b7b2057c4b15c766a0f313f8da0.jpg y su etiqueta
# Eliminados: 2001_129152_jpg.rf.fde6be13a645ab784621e8de68ad2852.jpg y su etiqueta
# Eliminados: 2001_129153_jpg.rf.b9daeaa4a18c137d2d4b9dce28218ea3.jpg y su etiqueta
# Eliminados: 2001_129158_jpg.rf.4f778081f37c60422121583693b0825e.jpg y su etiqueta
# Eliminados: 2001_129169_jpg.rf.283c3363319987dc2ff6f5661b61e5cb.jpg y su etiqueta
# Eliminados: 2001_129181_jpg.rf.fe3248ca90696f0787c4a1ea612eb9dd.jpg y su etiqueta
# Eliminados: 2001_129182_jpg.rf.3a89d63732bdac44a0cb82177211d6a2.jpg y su etiqueta
# Eliminados: 2001_129185_jpg.rf.24c33ab54756b50c0eb59197acb39565.jpg y su etiqueta
# Eliminados: 2001_149263_jpg.rf.8bfc25a90d505e15106ae32a88bd4224.jpg y su etiqueta
# Eliminados: 2001_149263_jpg.rf.c3c8a9603873a5b815a73357f31b0d22.jpg y su etiqueta
# Eliminados: 2001_149267_jpg.rf.5182c13af9ce1f2294c562d1643b59bb.jpg y su etiqueta
# Eliminados: 2001_149267_jpg.rf.fab887620feec9d18a59d8101bb81a5c.jpg y su etiqueta
# Eliminados: 2001_149280_jpg.rf.ee76a4d7d87352ada4a58a8d3df43e0a.jpg y su etiqueta
# Eliminados: 2001_149285_jpg.rf.d4a3cf93cc1cadd1c7dd8040b7faac97.jpg y su etiqueta
# Eliminados: 2001_149299_jpg.rf.3e68f6a71c7edfd3549f2168359bb8c9.jpg y su etiqueta
# Eliminados: 2001_149305_jpg.rf.e369a213ab78b9ea69ed3a3d9c89bec2.jpg y su etiqueta
# Eliminados: 2001_150978_jpg.rf.e2ef1934f5b75557697c0fbd1403b095.jpg y su etiqueta
# Eliminados: 2001_150989_jpg.rf.4b8c6fb67387d8312fde1e4048614564.jpg y su etiqueta
# Eliminados: 2001_151009_jpg.rf.68e385c4a354c6a7ea2c43fdd5cf9169.jpg y su etiqueta
# Eliminados: 2001_151018_jpg.rf.0c04015169292ad9abc288194c448e27.jpg y su etiqueta
# Eliminados: 2001_151020_jpg.rf.30ca2bdfbd52d56c578a1f21951e386e.jpg y su etiqueta
# Eliminados: 2001_7400_jpg.rf.c9ec8e2d8f2c277b8e3c0801fe2fa5a9.jpg y su etiqueta
# Eliminados: 2002_22882_jpg.rf.3bc55a8f139389dad434caa37f819e1a.jpg y su etiqueta
# Eliminados: 2002_365165_jpg.rf.95a68daadcb7388f270d9b0e92c0e4a6.jpg y su etiqueta
# Eliminados: 2002_365166_jpg.rf.6ef40457941181b28b7203a420e62415.jpg y su etiqueta
# Eliminados: 2002_365168_jpg.rf.4911e262fc11c9cc6caf3d2de9894106.jpg y su etiqueta
# Eliminados: 2002_365190_jpg.rf.ad537f014b75d706b1b30514a6a79713.jpg y su etiqueta
#
# ¡Proceso completado!

# %% [markdown]
# ### 📊 Conteo de etiquetas YOLO
#
# Este script recorre las carpetas `train`, `valid` y `test` de un dataset en formato YOLO y:
#
# - Cuenta cuántas etiquetas hay por clase en cada subconjunto.
# - Muestra cuántas imágenes hay por split.
# - Ignora líneas mal formateadas.
# - Al final, imprime un resumen total de etiquetas por clase y la cantidad total de etiquetas en todo el dataset.

# %%
import os
from collections import defaultdict

def count_labels(data_dir):
    splits = ['train', 'valid', 'test']
    total_counts = defaultdict(int)
    
    for split in splits:
        split_counts = defaultdict(int)
        labels_dir = os.path.join(data_dir, split, 'labels')
        
        if not os.path.exists(labels_dir):
            print(f"⚠️ Directorio no encontrado: {labels_dir}")
            continue
            
        num_images = len([f for f in os.listdir(os.path.join(data_dir, split, 'images')) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
        label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
        
        for label_file in label_files:
            with open(os.path.join(labels_dir, label_file), 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        continue  # Saltar líneas mal formateadas
                    class_id = parts[0]
                    split_counts[class_id] += 1
                    total_counts[class_id] += 1
        
        print(f"\n📊 Split: {split.upper()}")
        print(f"📁 Imágenes: {num_images}")
        print(f"🏷️ Etiquetas por clase:")
        for cls in sorted(split_counts, key=int):
            print(f"  Clase {cls}: {split_counts[cls]}")

    # Resultados totales
    print("\n🔍 TOTALES ACUMULADOS:")
    for cls in sorted(total_counts, key=int):
        print(f"  Clase {cls}: {total_counts[cls]}")
    print(f"🏷️ Total de etiquetas: {sum(total_counts.values())}")

# Configuración (cambiar por tu ruta)
data_dir = r'E:\Futsal\dataset'
# Ejecutar el conteo
count_labels(data_dir)
# Out:
# 📊 Split: TRAIN
# 📁 Imágenes: 18401
# 🏷️ Etiquetas por clase:
#   Clase 0: 20749
#   Clase 1: 1859
#
# 📊 Split: VALID
# 📁 Imágenes: 3810
# 🏷️ Etiquetas por clase:
#   Clase 0: 4147
#   Clase 1: 477
#
# 📊 Split: TEST
# 📁 Imágenes: 3573
# 🏷️ Etiquetas por clase:
#   Clase 0: 2692
#   Clase 1: 1228
#
# 🔍 TOTALES ACUMULADOS:
#   Clase 0: 27588
#   Clase 1: 3564
# 🏷️ Total de etiquetas: 31152

# %% [markdown]
# ### 🖼️ Conversión y redimensionamiento de imágenes
#
# Este script procesa todas las imágenes en una carpeta y realiza lo siguiente:
#
# - Convierte cada imagen a escala de grises (blanco y negro).
# - Redimensiona cada imagen a 640x640 píxeles.
# - Sobrescribe la imagen original con la versión modificada.

# %%
import os
from PIL import Image

# Ruta de la carpeta de imágenes

# Obtener lista de archivos de imágenes
images_dir = r"E:\Futsal\raw\images\test\images"


image_files = [f for f in os.listdir(images_dir) if f.endswith((".jpg", ".png"))]  # Ajusta extensiones si es necesario

for image_file in image_files:
    image_path = os.path.join(images_dir, image_file)

    # Abrir imagen, convertir a escala de grises y redimensionar
    img = Image.open(image_path).convert("L").resize((640, 640))
    
    # Guardar la imagen modificada
    img.save(image_path)

print("Todas las imágenes han sido convertidas a blanco y negro y redimensionadas a 640x640 píxeles.")
# Out:
# Todas las imágenes originales han sido reemplazadas con su versión en blanco y negro.

# %% [markdown]
# ### 🔀 Separación de datos de validación
#
# Este script toma el 10% de las imágenes del conjunto de entrenamiento (`train`) y las mueve al conjunto de validación (`valid`), junto con sus archivos de etiqueta.
#
# - Selecciona aleatoriamente el 10% de las imágenes en `train/images`.
# - Mueve esas imágenes a `valid/images`.
# - También mueve sus etiquetas correspondientes de `train/labels` a `valid/labels`.

# %%
import os
import shutil
import random

# Definir rutas
train_dir = r'E:\Futsal\FineTuning\dataset\train'
train_images_dir = os.path.join(train_dir, 'images')
train_labels_dir = os.path.join(train_dir, 'labels')

valid_dir = r'E:\Futsal\FineTuning\dataset\valid'
valid_images_dir = os.path.join(valid_dir, 'images')
valid_labels_dir = os.path.join(valid_dir, 'labels')

# Crear las carpetas de validación si no existen
os.makedirs(valid_images_dir, exist_ok=True)
os.makedirs(valid_labels_dir, exist_ok=True)

# Listar todas las imágenes en la carpeta de train/images
imagenes = os.listdir(train_images_dir)
total_imagenes = len(imagenes)

# Calcular el 10% de las imágenes
cantidad_valid = int(total_imagenes * 0.10)

# Seleccionar al azar las imágenes a mover
seleccionadas = random.sample(imagenes, cantidad_valid)

# Mover cada imagen y su label correspondiente
for imagen in seleccionadas:
    # Obtener el nombre base de la imagen (sin extensión)
    nombre_base, extension = os.path.splitext(imagen)
    
    # Rutas de origen para imagen y label
    origen_imagen = os.path.join(train_images_dir, imagen)
    origen_label = os.path.join(train_labels_dir, nombre_base + '.txt')
    
    # Rutas destino para imagen y label
    destino_imagen = os.path.join(valid_images_dir, imagen)
    destino_label = os.path.join(valid_labels_dir, nombre_base + '.txt')
    
    # Mover la imagen
    shutil.move(origen_imagen, destino_imagen)
    
    # Mover la etiqueta si existe
    if os.path.exists(origen_label):
        shutil.move(origen_label, destino_label)
    else:
        print(f"No se encontró el archivo de etiqueta para {imagen}")

print(f"Se movieron {cantidad_valid} imágenes y sus etiquetas a la carpeta '{valid_dir}'.")
# Out:
# Se movieron 102 imágenes y sus etiquetas a la carpeta 'E:\Futsal\FineTuning\dataset\valid'.
